# %% [markdown]
# <a href="https://colab.research.google.com/github/HyoenminPark/class2021Fall/blob/main/sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %% [markdown]
# ### Phasor

# %% [markdown]
# sampling rate가 10hz 한 sample이 의미하는 초는? 1/10
# sampling rate가 10000hz 한 sample이 담당하는 초는? 1/10000

# %% [markdown]
# x축에 각도가 오게 sine 곡선을 만들었지만 실제로 나타날 때는 X축이 시간이 되어야 함
#
# sin(radian) -> 시간
#
# sampling rate

# %%
# parameter setting
amp = 1          # range [0.0, 1.0]
sr = 10000       # sampling rate, Hz
dur = 0.5        # in seconds #duration이 끝날 때 sample은 5000번째
freq = 1000.0     # sine frequency, Hz / 0.5 -> 50번 
phase = np.pi/2  # phase, radian 90도로 시작하겠다!

# %%
# generate samples
nSamp = sr * dur #5000개의 sample이 만들어진다!
samples = np.arange(1, nSamp+1) #번호를 generate 대신 마지막꺼는 하나 빠지니까 +1

# %%
# convert samples to time
t = samples/sr #만분의 일초, 만분의 이초,,,,,, 만분의 오천초

# %%
# convert time to angle in radian
theta0 = t * 2*np.pi * freq #0....1*2pi -> 0.....1*2pi + *freq

# %%
# shift angle by phase
theta = theta0 + phase

# %%
# generate signal by sin-phasor
s = amp * np.sin(theta)

# %%
# plot the entire signal
plt.plot(t, s, ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
# plot a certain of signals
sampleRng = np.arange(0,1000)
plt.plot(t[sampleRng], s[sampleRng], ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
ipd.Audio(s, rate=10000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; dur = 1; freq = 440; phase = 0
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
amp = 1; sr = 10000; dur = 1; freq = 880; phase = 100 #PHASE는 지각하는 소리에는 영향 X
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
amp=1; ar=10000; phase=0
A=440.00
C=523.25
F=698.46
D=587.33
E=659.25
Eb=622.25
F=698.46
G=783.99
Bb=932.33

s_all=np.empty(0)

# %%
a,t,theta=phasor_sine(amp,sr,0.25,F,phase)
a_all=np.concatenate((s_all,s))

# %%
notes = [C,A, D, C, D,E,E,A,D,D,E,D,E,E,E,A,C,D,F,E,E,F,D,Eb,G,D]

durs = [0.5, 0.75, 0.25, 0.5, 0.5,0.5, 1.0, 0.5, 0.5, 1.0, 0.5, 0.5, 1.0, 0.75, 0.25, 0.5, 0.5, 0.5, 0.5, 1.0, 0.5,0.5,0.5,0.5,2]

# %%
s_all = np.empty(0)   

for note, dur in zip(notes, durs):        
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
notes = [F,D,0,D,Eb,F,D*2,0,D*2,0,Bb,0,F,D,0,Eb,D,F,0,F,0,Eb,0]

durs = [0.5, 0.75, 0.25, 0.5, 0.5,0.5, 1.0, 0.5, 0.5, 1.0, 0.5, 0.5, 1.0, 0.75, 0.25, 0.5, 0.5, 0.5, 0.5, 1.0, 0.5,0.5,0.5]

# %% [markdown]
# ### Dividing signal by the window size and step

# %%
def frame_signal(signal, srate, win_size, win_step):
    frame_size = int(win_size * srate)
    frame_step = int(win_step * srate)

    # Get number of frames
    num_frames = int(np.ceil(np.abs(len(signal) - frame_size) / frame_step))
    # Pad signal
    pad_len = num_frames * frame_step + frame_size
    pad = np.zeros((pad_len - len(signal)))
    signal_padded = np.append(signal, pad)
    # Get within-frame sample indices
    idx1 = np.tile(np.arange(0, frame_size), (num_frames, 1))
    # Get vectors of frame_step increments
    idx2 = np.tile(np.arange(0, num_frames * frame_step, frame_step),
                   (frame_size, 1)).T
    # Get total indices divided by each frame
    indices = idx1 + idx2
    # Get frames divided by each frame based on indices
    frames = signal_padded[indices.astype(np.int32, copy=False)]
#     if cutoff is not None:
#         cutoff_bin = round(cutoff * nfft / (srate))  # hz -> bin
#         frames = frames[:, :cutoff_bin]
    return frames

# %% [markdown]
# ### Load a wav file and frame signal

# %%
from scipy.io import wavfile
sr, s = wavfile.read('a.wav')

s = s/np.max(np.abs(s))
t = np.arange(1, len(s)+1)/sr

win_size = 0.05
win_step = 0.05

frames = frame_signal(s, sr, win_size, win_step)
framesT = np.arange(frames.shape[0]) * win_step + win_size/2

ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Intensity by RMS

# %%
amp = []
for frame in frames:
  amp.append(np.sqrt(np.mean(frame**2)))

plt.subplot(2,1,1)
plt.plot(t, s)
plt.xlim([0, t[-1]])
plt.subplot(2,1,2)
plt.plot(framesT, amp, '.')
plt.xlim([0, t[-1]])
plt.show()

# %% [markdown]
# ### Pitch by autocorrelation

# %%
def autocorr(s):
    result = np.correlate(s, s, mode='full')
    maxID = np.argmax(result)
    return result[maxID:]/result[maxID]

# %%
F0 = []
for frame in frames:
  result = autocorr(frame)
  peakIdx = np.argmin(result) + np.argmax(result[np.argmin(result):])
  if result[peakIdx] >= 0.5:
    F0.append(1/(peakIdx/sr))
  else:
    F0.append(np.nan)

plt.subplot(2,1,1)
plt.plot(t, s)
plt.xlim([0, t[-1]])
plt.subplot(2,1,2)
plt.plot(framesT, F0, '.')
plt.xlim([0, t[-1]])
plt.show()

# %% [markdown]
# ### Play musical notes

# %%
def getFrequency(note):
    A4=440
    notes = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']

    octave = int(note[2]) if len(note) == 3 else int(note[1])
        
    keyNumber = notes.index(note[0:-1]);
    
    if (keyNumber < 3) :
        keyNumber = keyNumber + 12 + ((octave - 1) * 12) + 1; 
    else:
        keyNumber = keyNumber + ((octave - 1) * 12) + 1; 

    return A4 * 2** ((keyNumber- 49) / 12)

# %%
amp = 1; sr = 10000; phase = 0

A4  = getFrequency('A4')
C5  = getFrequency('C5')
F5  = getFrequency('F5')
D5  = getFrequency('D5')
E5  = getFrequency('E5')	 
Eb5 = getFrequency('D#5') 
F5  = getFrequency('F5') 
G5  = getFrequency('G5')
Bb5 = getFrequency('A#5')
D6 = getFrequency('D6')

# %%
# The bridge on the river Kwai

notes = [F5, D5, 0, D5, Eb5, F5, D6, 0, D6, 0, Bb5, 0, \
         F5, D5, 0, D5, Eb5, D5, F5, 0, F5, 0, Eb5, 0, \
         Eb5, C5, 0, C5, D5, Eb5, F5, D5, 0, D5, E5, D5, \
         C5, F5, D5, E5, C5, G5, F5]

durs = [0.25, 0.75, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.75, 0.25, \
        0.25, 0.75, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.75, 0.25, \
        0.25, 0.75, 0.25, 0.25, 0.25, 0.25, 0.25, 0.75, 0.25, 0.25, 0.25, 0.25, \
        0.25, 0.5, 0.25, 0.25, 0.5, 0.25, 1.5]

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
